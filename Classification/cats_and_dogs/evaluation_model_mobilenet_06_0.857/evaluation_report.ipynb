# %% [markdown]
# # Initialisation and Prediction

# %% [markdown]
# ## Initialisation

# %%
from imageatm.components import Evaluation
# Out:
# /Users/hamin/miniconda3/envs/image-classification/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/hamin/miniconda3/envs/image-classification/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/hamin/miniconda3/envs/image-classification/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/hamin/miniconda3/envs/image-classification/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/hamin/miniconda3/envs/image-classification/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/hamin/miniconda3/envs/image-classification/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
image_dir = None
job_dir = None

# %%
# Parameters
image_dir = "/Users/hamin/Classification/cats_and_dogs/train"
job_dir = "/Users/hamin/Classification/cats_and_dogs"

# %%
e = Evaluation(image_dir=image_dir, job_dir=job_dir)
# Out:
# ****** Load model ******
# loaded /Users/hamin/Classification/cats_and_dogs/models/model_mobilenet_06_0.857.hdf5

# %% [markdown]
# ## Label prediction (on test set)

# %%
e._make_prediction_on_test_set()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# # Label distribution (in test set)

# %%
e._plot_test_set_distribution(figsize=[8, 5])

# %% [markdown]
# # Classification report

# %%
e._print_classification_report()
# Out:
#    	prec	rec	f1	support
# Cat	1.00	0.50	0.67	4
# Dog	0.71	1.00	0.83	5
# macro avg	0.86	0.75	0.75	9
# weighted avg	0.84	0.78	0.76	9

# %% [markdown]
# # Confusion matrix

# %% [markdown]
# ## Confusion matrix (recall)

# %%
e._plot_confusion_matrix(figsize=[max(9,e.n_classes*0.9), max(8,e.n_classes*0.9)])

# %% [markdown]
# ## Confusion matrix (precision)

# %%
e._plot_confusion_matrix(figsize=[max(9,e.n_classes*0.9), max(8,e.n_classes*0.9)], precision=True)

# %% [markdown]
# # Correct and wrong examples

# %%
e._plot_correct_wrong_examples()
# Out:
# Empty list.
